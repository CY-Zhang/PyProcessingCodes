# %% [markdown]
# Load deformation_level_0/1.dat.bz2 file to visulize deformation detected by NRR and thus visulize the artifact generated by low start level and small lambda value

# %%
import os
import scipy.io as sio
import scipy.misc as smisc
import numpy as np
import re as regexp
import math
import matplotlib.pyplot as plt
import scipy

from scipy import ndimage as ndi
import matplotlib.pyplot as plt
from skimage.feature import peak_local_max
from skimage import data, img_as_float

import scipy.io
import time
import glob,os
import cv2
from scipy import optimize
from pylab import *

import cv2
import csv

import struct
import bz2

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(121)
plt.quiver(y_deform_ref[::8,::8], x_deform_ref[::8,::8])
# plt.axis('off')

ax = fig.add_subplot(122)
temp = LoadImage('/srv/home/chenyu/NRR/STO_NRR/ArtifactPlot/StartLevel_7/stage1/defTempl_'+"{:0>3d}".format(nframe)+'.dat.bz2')
plt.imshow(np.fliplr(np.transpose(temp)),cmap='gray')
# plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-919928363203> in <module>()
#       1 fig = plt.figure(figsize=(10,6))
#       2 ax = fig.add_subplot(121)
# ----> 3 plt.quiver(y_deform_ref[::8,::8], x_deform_ref[::8,::8])
#       4 # plt.axis('off')
#       5
#
# NameError: name 'y_deform_ref' is not defined

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(121)
plt.quiver(y_deform_StartLevel3[::8,::8], x_deform_StartLevel3[::8,::8])
# plt.axis('off')

ax = fig.add_subplot(122)
temp = LoadImage('/srv/home/chenyu/NRR/STO_NRR/ArtifactPlot/StartLevel_3/stage1/defTempl_'+"{:0>3d}".format(nframe)+'.dat.bz2')
plt.imshow(np.fliplr(np.transpose(temp)),cmap='gray')
# plt.axis('off')

# %%
# data loaded from q2bz file has reversed x and y axis

fig = plt.figure(figsize=(15,10))

path = '/srv/home/chenyu/NRR/STO_NRR/DoseTest/Data/1/HAADF_000.dat'
img = LoadDatImage(path)
ax = fig.add_subplot(241)
plt.imshow(np.fliplr(np.transpose(img))[0:60,0:60],cmap='gray')
plt.xticks([], [])
plt.yticks([], [])

path = '/srv/home/chenyu/NRR/STO_NRR/DoseTest/Data/1/HAADF_003.dat'
img = LoadDatImage(path)
ax = fig.add_subplot(245)
plt.imshow(np.fliplr(np.transpose(img))[0:60,0:60],cmap='gray')
plt.xticks([], [])
plt.yticks([], [])

ax = fig.add_subplot(242)
plt.quiver(y_deform_ref[::20,::20], x_deform_ref[::20,::20],linewidths=1, edgecolors='k', headlength = 7, scale=0.1)
plt.axis('scaled')
plt.xticks([], [])
plt.yticks([], [])

ax = fig.add_subplot(243)
plt.quiver(y_deform_StartLevel3[::20,::20], x_deform_StartLevel3[::20,::20],linewidths=1, edgecolors='k', headlength = 7, scale=0.7)
plt.axis('scaled')
plt.xticks([], [])
plt.yticks([], [])

ax = fig.add_subplot(244)
plt.quiver(y_deform_lambda[::20,::20], x_deform_lambda[::20,::20],linewidths=1, edgecolors='k', headlength = 7, scale=0.1)
plt.axis('scaled')
plt.xticks([], [])
plt.yticks([], [])

ax = fig.add_subplot(246)
temp = LoadImage('/srv/home/chenyu/NRR/STO_NRR/ArtifactPlot/StartLevel_7/stage1/defTempl_'+"{:0>3d}".format(nframe)+'.dat.bz2')
plt.imshow(np.fliplr(np.transpose(temp))[0:60,0:60],cmap='gray')

# plt.axis('off')
plt.xticks([], [])
plt.yticks([], [])

ax = fig.add_subplot(247)
temp = LoadImage('/srv/home/chenyu/NRR/STO_NRR/ArtifactPlot/StartLevel_3/stage1/defTempl_'+"{:0>3d}".format(nframe)+'.dat.bz2')
plt.imshow(np.fliplr(np.transpose(temp))[0:60,0:60],cmap='gray')
# plt.axis('off')
plt.xticks([], [])
plt.yticks([], [])

ax = fig.add_subplot(248)
temp = LoadImage('/srv/home/chenyu/NRR/STO_NRR/ArtifactPlot/Lambda_0.01/stage1/defTempl_'+"{:0>3d}".format(nframe)+'.dat.bz2')
plt.imshow(np.fliplr(np.transpose(temp))[0:60,0:60],cmap='gray')
# plt.axis('off')
plt.xticks([], [])
plt.yticks([], [])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
nframe = 3

# %%
# Deformation from too small start level = 3
path = '/srv/home/chenyu/NRR/STO_NRR/ArtifactPlot/StartLevel_3/stage1/'+ str(nframe)+'/deformation_08_0.dat.bz2'
x_deform_StartLevel3 = LoadImage(path)
path = '/srv/home/chenyu/NRR/STO_NRR/ArtifactPlot/StartLevel_3/stage1/'+ str(nframe)+'/deformation_08_1.dat.bz2'
y_deform_StartLevel3 = LoadImage(path)
plt.quiver( x_deform_StartLevel3[::16,::16], y_deform_StartLevel3[::16,::16])
# plt.quiver(x_deform, y_deform)

# %%
# Deformation from default parameter: lambda = 200, start level = 7
path = '/srv/home/chenyu/NRR/STO_NRR/ArtifactPlot/StartLevel_7/stage1/'+ str(nframe)+'/deformation_08_0.dat.bz2'
x_deform_ref = LoadImage(path)
path = '/srv/home/chenyu/NRR/STO_NRR/ArtifactPlot/StartLevel_7/stage1/'+ str(nframe)+'/deformation_08_1.dat.bz2'
y_deform_ref = LoadImage(path)
plt.quiver( x_deform_ref[::16,::16], y_deform_ref[::16,::16])
# plt.quiver(x_deform, y_deform)

# %%
# Deformation from too small lambda = 0.01
path = '/srv/home/chenyu/NRR/STO_NRR/ArtifactPlot/Lambda_0.01/stage1/'+ str(nframe)+'/deformation_08_0.dat.bz2'
x_deform_lambda = LoadImage(path)
path = '/srv/home/chenyu/NRR/STO_NRR/ArtifactPlot/Lambda_0.01/stage1/'+ str(nframe)+'/deformation_08_1.dat.bz2'
y_deform_lambda = LoadImage(path)
plt.quiver( x_deform_lambda[::16,::16], y_deform_lambda[::16,::16])
# plt.quiver(x_deform, y_deform)

# %%
def LoadImage(path):
#     path = '/srv/home/chenyu/NRR/STO_NRR/ParameterTest/Lambda/100/HAADF_NRR/stage3/average.q2bz'
    # read header in read text mode
    fid = bz2.open(path, mode='rt',encoding = "ISO-8859-1")
    next(fid)    # magic number P9, skip
#     print(fid.readline())   # description line
    fid.readline()    # do not print, but read the description line
    size = fid.readline()   # image size in width, height
    width = int(size.split(' ')[0])
    height = int(size.split(' ')[1][:-1])
#     print(width, height)
#     print(fid.readline())   # max?
    # each number is a 8 byte double format

    # read data part in read binary mode
    img = np.zeros((height,width))
    fid = bz2.open(path, mode='rb')
    for _ in range(4):
        next(fid)
    for icol in range(width):
        for irow in range(height):
            read_bytes = fid.read(8)
            img[irow,icol] = struct.unpack('d',read_bytes)[0]

#     plt.imshow(img)
#     plt.colorbar()
    return img

# %%
path = '/srv/home/chenyu/NRR/STO_NRR/DoseTest/Data/1/HAADF_000.dat'
img = LoadDatImage(path)
plt.imshow(np.fliplr(np.transpose(img)))

# %%
def LoadDatImage(path):
#     path = '/srv/home/chenyu/NRR/STO_NRR/ParameterTest/Lambda/100/HAADF_NRR/stage3/average.q2bz'
    # read header in read text mode
    fid = open(path, mode='rt',encoding = "ISO-8859-1")
    next(fid)    # magic number P9, skip
#     print(fid.readline())   # description line
    fid.readline()
    size = fid.readline()   # image size in width, height
    width = int(size.split(' ')[0])
    height = int(size.split(' ')[1][:-1])
#     print(width, height)
#     print(fid.readline())   # max?
    # each number is a 8 byte double format

    # read data part in read binary mode
    img = np.zeros((height,width))
    fid = open(path, mode='rb')
    for _ in range(4):
        next(fid)
    for icol in range(width):
        for irow in range(height):
            read_bytes = fid.read(8)
            img[irow,icol] = struct.unpack('d',read_bytes)[0]

#     plt.imshow(img)
#     plt.colorbar()
    return img
