# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import math
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# Analysis eigenvalues
# load the eigenvalues calculated from Matlab
temp = sio.loadmat('/srv/home/chenyu/TensorDenoise/Simulatons/STO_simulation/Simulation_noisy_STO_slice_5_1000FPS_fullsize_eigenvalue.mat')

fig = plt.figure(figsize=(14,5))

ax = fig.add_subplot(131)
e1 = temp['e1']
e1 = e1[::-1]
plt.plot(np.linspace(1,7,7),np.log(e1[0:7]),'o',linewidth='2',label = 'principle components')
plt.plot(np.linspace(8,18,10),np.log(e1[8:18]),'o',linewidth='2',label='noise components')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.axvline(x=7,color='r',ls='--')
plt.ylabel('log(Eigenvalues)',fontsize=14)
plt.xlabel('Components',fontsize=14)
# ax.text(2,11.8,'a',fontsize=20, color='black', fontweight='bold')
plt.title('rank($\it{r_x})_{optimal}$=7',color='red',fontsize=20)
ax.tick_params(direction='in')

ax = fig.add_subplot(132)
e2 = temp['e2']
e2 = e2[::-1]
plt.plot(np.linspace(1,7,7),np.log(e2[0:7]),'o',linewidth='2',label = 'principle components')
plt.plot(np.linspace(8,18,10),np.log(e2[8:18]),'o',linewidth='2',label='noise components')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.axvline(x=7,color='r',ls='--')
plt.xlabel('Components',fontsize=14)
# ax.text(2,11.8,'b',fontsize=20, color='black', fontweight='bold')
plt.title('rank($\it{r_y})_{optimal}$=7',color='red',fontsize=20)
ax.tick_params(direction='in')


ax = fig.add_subplot(133)
e3 = temp['e3']
e3 = e3[::-1]
plt.plot(np.linspace(1,27,27),np.log(e3[0:27]),'o',linewidth='2',label = 'principle components')
plt.plot(np.linspace(27,50,23),np.log(e3[27:50]),'o',linewidth='2',label='noise components')
plt.legend(fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.axvline(x=30,color='r',ls='--')
plt.xlabel('Components',fontsize=14)
# ax.text(5,11.7,'c',fontsize=20, color='black', fontweight='bold')
plt.title('rank($\it{k})_{optimal}$=30',color='red',fontsize=20)
ax.tick_params(direction='in')

fig.savefig('/srv/home/chenyu/TensorDenoise/Simulatons/STO_simulation/STO_sim_screePlots.tif')

# %%
# Analysis eigenvalues
temp = sio.loadmat('/srv/home/chenyu/TensorDenoise/Simulatons/Si_dislocation_simulations/Simulation_noisy_SiDisl_slc5_1000FPS_eigenvalue.mat')

fig = plt.figure(figsize=(14,5))

ax = fig.add_subplot(131)
e1 = temp['e1']
e1 = e1[::-1]
plt.plot(np.linspace(1,29,29),np.log(e1[0:29]),'o',linewidth='2',label = 'principle components')
plt.plot(np.linspace(30,50,20),np.log(e1[30:50]),'o',linewidth='2',label='noise components')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.axvline(x=31,color='r',ls='--')
plt.ylabel('log(Eigenvalues)',fontsize=14)
plt.xlabel('Components',fontsize=14)
# ax.text(5,11.5,'d',fontsize=20, color='black', fontweight='bold')
plt.title('rank($\it{r_x})_{optimal}$=32',color='red',fontsize=20)

ax = fig.add_subplot(132)
e2 = temp['e2']
e2 = e2[::-1]
plt.plot(np.linspace(1,29,29),np.log(e2[0:29]),'o',linewidth='2',label = 'principle components')
plt.plot(np.linspace(30,50,20),np.log(e2[30:50]),'o',linewidth='2',label='noise components')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.axvline(x=31,color='r',ls='--')
plt.xlabel('Components',fontsize=14)
# ax.text(5,11.5,'e',fontsize=20, color='black', fontweight='bold')
plt.title('rank($\it{r_y})_{optimal}$=32',color='red',fontsize=20)


ax = fig.add_subplot(133)
e3 = temp['e3']
e3 = e3[::-1]
plt.plot(np.linspace(1,180,180),np.log(e3[0:180]),'o',linewidth='2',label = 'principle components')
plt.plot(np.linspace(180,400,220),np.log(e3[180:400]),'o',linewidth='2',label='noise components')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.axvline(x=180,color='r',ls='--')
plt.xlabel('Components',fontsize=14)
# ax.text(35,11.3,'f',fontsize=20, color='black', fontweight='bold')
plt.title('rank($\it{k})_{optimal}$=180',color='red',fontsize=20)
fig.savefig('/srv/home/chenyu/TensorDenoise/Simulatons/Si_dislocation_simulations/SiDisl_sim_screePlot.tif')

# %%
fig = plt.figure(figsize=(5,5))

# ax = fig.add_subplot(131)
e1 = temp['e1']
e1 = e1[::-1]
plt.plot(np.linspace(1,7,7),np.log(e1[0:7]),'o',linewidth='2',label = 'principle components')
plt.plot(np.linspace(8,15,7),np.log(e1[8:15]),'o',linewidth='2',label='noise components')
plt.legend(fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.axvline(x=7,color='r',ls='--')
plt.ylabel('log(Eigenvalues)',fontsize=14)
plt.xlabel('Components',fontsize=14)
# ax.text(2,11.8,'a',fontsize=20, color='black', fontweight='bold')
# Out:
# Text(0.5, 0, 'Components')
