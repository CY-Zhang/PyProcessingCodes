# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import h5py

# %%
data = sio.loadmat('/srv/home/chenyu/TensorDenoise/MemoryTest/Memory_time_test.mat')

# %%
mem_list = data['mem_list']
size_list = data['size_list']
time_list = data['time_list']

# %%
print(mem_list)
z = np.polyfit(mem_list[1,:],mem_list[0,:],1)
print(z)
p = np.poly1d(z)
plt.plot(mem_list[1,:],p(mem_list[1,:]))
plt.scatter(mem_list[1,:],mem_list[0,:])
# Out:
# [[3.61267200e+06 1.09568000e+07 1.75144960e+07 2.47275520e+07
#   3.20102400e+07 3.95632640e+07 4.47283200e+07 5.34650880e+07]
#  [1.80633600e+06 5.41900800e+06 9.02348800e+06 1.26279680e+07
#   1.62365440e+07 1.98451200e+07 2.34496000e+07 2.70540800e+07]
#  [1.59363072e+08 4.78085120e+08 7.96798976e+08 1.11551693e+09
#   1.43423488e+09 1.93983283e+09 2.70930739e+09 3.60666726e+09]]
# [1.95158746e+00 1.55494907e+05]

# %%
print(mem_list)
z = np.polyfit(mem_list[1,:],mem_list[2,:],2)
print(z)
p = np.poly1d(z)
plt.plot(mem_list[1,:],p(mem_list[1,:]))
plt.scatter(mem_list[1,:],mem_list[2,:])
# Out:
# [[3.61267200e+06 1.09568000e+07 1.75144960e+07 2.47275520e+07
#   3.20102400e+07 3.95632640e+07 4.47283200e+07 5.34650880e+07]
#  [1.80633600e+06 5.41900800e+06 9.02348800e+06 1.26279680e+07
#   1.62365440e+07 1.98451200e+07 2.34496000e+07 2.70540800e+07]
#  [1.59363072e+08 4.78085120e+08 7.96798976e+08 1.11551693e+09
#   1.43423488e+09 1.93983283e+09 2.70930739e+09 3.60666726e+09]]
# [3.93252863e-06 1.53375343e+01 2.20885862e+08]

# %%
print(mem_list)
# Out:
# [[3.61267200e+06 1.09568000e+07 1.75144960e+07 2.47275520e+07
#   3.20102400e+07 3.95632640e+07 4.47283200e+07 5.34650880e+07]
#  [1.80633600e+06 5.41900800e+06 9.02348800e+06 1.26279680e+07
#   1.62365440e+07 1.98451200e+07 2.34496000e+07 2.70540800e+07]
#  [1.59363072e+08 4.78085120e+08 7.96798976e+08 1.11551693e+09
#   1.43423488e+09 1.93983283e+09 2.70930739e+09 3.60666726e+09]]

# %%
plt.plot(mem_list[1,:],mem_list[0,:])
plt.plot(mem_list[1,:],mem_list[1,:])
plt.plot(mem_list[1,:],mem_list[2,:])

# %%
plt.plot(size_list[0,0:8],time_list[0,:])
plt.plot(size_list[0,0:8],time_list[1,:])
plt.plot(size_list[0,0:8],time_list[2,:])
