# %% [markdown]
# # Goal of this script is to analysis rotation relationship between real space scan and reciprocal space diffraction

# %%
import os
import scipy.io as sio
import scipy.misc as smisc
import numpy as np
import math
import matplotlib.pyplot as plt
import scipy
import csv

from scipy import ndimage as ndi
import matplotlib.pyplot as plt
from skimage.feature import peak_local_max
from skimage import data, img_as_float

import scipy.io
import time
import glob,os
from scipy import optimize
from pylab import *

# %%
# Load sample configuration image acquired from DE camera
DE_acq = '/srv/home/chenyu/DEbackup/082519/SampleConfig/'
accumulated = np.zeros((2048,2048))
for i in range(len(glob.glob('/srv/home/chenyu/DEbackup/082519/SampleConfig/*.npy'))):
    temp = np.load(glob.glob('/srv/home/chenyu/DEbackup/082519/SampleConfig/*.npy')[i])
    accumulated = accumulated + temp

# %%
glob.glob('/srv/home/chenyu/DEbackup/082519/SampleConfig/*.npy')
# Out:
# ['/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00020.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00012.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00002.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00005.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00028.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00015.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00024.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00013.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00026.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00010.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00031.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00025.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00004.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00009.npy',
#  '/srv/home/chenyu/DEbackup/082519/SampleConfig/S0_00007.npy',
# ...

# %%
plt.imshow(accumulated[500:1500,500:1500])

# %%
kx = 512
ky = 512
kx = np.linspace(0,kx-1,kx)
ky = np.linspace(0,ky-1,ky)
weights_x, weights_y = np.meshgrid(kx,ky)

# %%
plt.imshow(weights_y)
