# %%
import os
import scipy.io as sio
import scipy.misc as smisc
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageEnhance
import cv2
import scipy.misc
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %% [markdown]
# ## Jason would like enhanced contrast on the image

# %%
im = Image.open('D:/2020/RemoteEpiHeusler/100619_GdPtSb/im_3.tif')
im_array = np.asarray(im)
im_array = im_array.astype('float')
fig = plt.figure(figsize=[10,10])
plt.imshow(im,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 1023.5, 1023.5, -0.5)

# %%
# Test1: calculate gradient of the 2D image array
im_grad = np.gradient(im_array)
im_grad = np.asarray(im_grad)
im_grad.shape
im_grad[0,:,:]
im_grad_mag = np.sqrt(im_grad[0,:,:]*im_grad[0,:,:]+im_grad[1,:,:]*im_grad[1,:,:])

# %%
fig = plt.figure(figsize=[10,10])
plt.imshow(im_grad_mag,cmap='gray',clim=[0,1000])
plt.axis('off')
plt.colorbar()

# %%
fig = plt.figure(figsize=[10,10])
plt.imshow(im_grad[1,:,:],cmap='gray',clim=[-1000,1000])
plt.axis('off')
plt.colorbar()
plt.imsave('Gradient.tiff', im_grad[1,:,:], cmap='gray',vmin=-1000, vmax=1000)

# %%
# Test 2: Use a differen colormap
fig = plt.figure(figsize=[10,10])
plt.imshow(im,cmap='RdBu')
# plt.axis('off')
# plt.imsave('Linear_RedBlue.tiff', np.log(im), cmap='RdBu')

# %%
# Test3: use square root of intensity
fig = plt.figure(figsize=[10,10])
temp = np.log(im_array)
ax = plt.gca()
im = ax.imshow(temp,cmap='RdBu')
plt.axis('off')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.4, )
cbar = plt.colorbar(im, cax=cax, ticks=[])
# fig.savefig('test.tif')

# plt.imsave('D:/2020/RemoteEpiHeusler/100619_GdPtSb/FiguresForDongxue_enhancedContrast/Interface_2.tiff', temp, cmap='RdBu')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-9b64b9da0d49> in <module>()
#       6 plt.axis('off')
#       7 divider = make_axes_locatable(ax)
# ----> 8 cax = divider.append_axes("right", size="5%", pad=0.4, height="50%")
#       9 cbar = plt.colorbar(im, cax=cax, ticks=[])
#      10 # fig.savefig('test.tif')
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\axes_grid1\axes_divider.py in append_axes(self, position, size, pad, add_to_figure, **kwargs)
#     621             ax = self.new_horizontal(size, pad, pack_start=True, **kwargs)
#     622         elif position == "right":
# --> 623             ax = self.new_horizontal(size, pad, pack_start=False, **kwargs)
#     624         elif position == "bottom":
#     625             ax = self.new_vertical(size, pad, pack_start=True, **kwargs)
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\axes_grid1\axes_divider.py in new_horizontal(self, size, pad, pack_start, **kwargs)
#     554             locator = self.new_locator(
#     555                 nx=len(self._horizontal) - 1, ny=self._yrefindex)
# --> 556         ax = self._get_new_axes(**kwargs)
#     557         ax.set_axes_locator(locator)
#     558         return ax
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\axes_grid1\axes_divider.py in _get_new_axes(self, axes_class, **kwargs)
#     507                 axes_class = type(axes)
#     508         return axes_class(axes.get_figure(), axes.get_position(original=True),
# --> 509                           **kwargs)
#     510
#     511     def new_horizontal(self, size, pad=None, pack_start=False, **kwargs):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     466             self.set_yscale(yscale)
#     467
# --> 468         self.update(kwargs)
#     469
#     470         if self.xaxis is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'Axes' object has no property 'height'

# %%
# Test 4: show a small patch of image with enhanced contrast
im = Image.open('D:/2020/RemoteEpiHeusler/100619_GdPtSb/im_9.tif')
im_array = np.asarray(im)
im_array = im_array.astype('float')
fig = plt.figure(figsize=[10,10])
temp = im_array[600:800,200:400]
plt.imshow(np.sqrt(temp),cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 199.5, 199.5, -0.5)

# %%
im = Image.open('D:/2020/RemoteEpiHeusler/100619_GdPtSb/im_9.tif')
im_array = np.asarray(im)
im_array = im_array.astype('float')
fig = plt.figure(figsize=[10,10])
temp = im_array[100:300,600:800]
plt.imshow(np.sqrt(temp),cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 199.5, 199.5, -0.5)

# %%
# Test 5: change the gamma factor
im_array?

# %%
def adjust_gamma(image, gamma=1.0):

   invGamma = 1.0 / gamma
   table = np.array([((i / 255.0) ** invGamma) * 255
      for i in np.arange(0, 256)]).astype("uint8")

   return cv2.LUT(image, table)

# %%
x = 'D:/2020/RemoteEpiHeusler/100619_GdPtSb/im_9.tif'  #location of the image
original = cv2.imread(x, 1)
# cv2.imshow('original',original)

gamma = 1.3                                  # change the value here to get different result
adjusted = adjust_gamma(original, gamma=gamma)
# cv2.putText(adjusted, "g={}".format(gamma), (10, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 3)
# cv2.imshow("gammam image 1", adjusted)

# %%
fig = plt.figure(figsize=[10,10])
plt.imshow(adjusted)
