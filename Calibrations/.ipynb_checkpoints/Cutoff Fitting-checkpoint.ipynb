# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import struct
import scipy.misc as smisc

# %%
x = [0.337,0.342,0.347,0.352]
y = [105.03,89.99,77.29,70.78]

mymodel = np.poly1d(np.polyfit(x, y, 2))

plt.scatter(x, y)
plt.plot(x, mymodel(x))
plt.show()
print(mymodel)
# Out:
#           2
# 8.53e+04 x - 6.108e+04 x + 1.1e+04

# %%
filelist = glob.glob('/srv/home/chenyu/DEbackup/030120/SourceSize/CL160_CollectionAngle*')
frame = np.zeros(2048)
for i in range(len(filelist)):
    frame = frame + loadMRCfile(filelist[i])

# %%
plt.imshow(frame)
smisc.imsave('/srv/home/chenyu/DEbackup/030120/SourceSize/Accumulated_apt70.tiff',frame)
# Out:
# /srv/home/chenyu/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
def loadMRCfile(filepath):
    with open(filepath, mode='rb') as file: # b is important -> binary
        file.seek(0)
        read_bytes = file.read(8)
        frame_width = struct.unpack('<i',read_bytes[0:4])
        frame_width = frame_width[0]
        frame_height = struct.unpack('<i',read_bytes[4:8])
        frame_height = frame_height[0]
        image = np.zeros((frame_height,frame_width))
        file.seek(256*4)
        dataset = file.read(frame_width*frame_height*4)
        for irow in range(frame_height):
            for icol in range(frame_width):
                pixel = struct.unpack('<f',dataset[(irow*frame_width+icol)*4:(irow*frame_width+icol+1)*4])[0]
                image[irow,icol] = pixel
        return image
