# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import scipy.io
import time
import glob,os
import cv2
from scipy import optimize
from skimage import feature
from pylab import *

from skimage import data, color
from skimage.transform import hough_circle, hough_circle_peaks
from skimage.feature import canny
from skimage.draw import circle_perimeter
from skimage.util import img_as_ubyte

# %%
path = '/srv/home/chenyu/DEbackup/071519/100us_delay/npy/'
rrow = 20
rcol = 20

# %%
irow = 2
icol = 16
isample = irow*rrow + icol + 1
sample = np.load(path+'S0_'+format(isample,'05')+'.npy')
sample[sample<15]=0
plt.imshow(sample[450:550,500:1000],clim=[0,100])
# plt.axis('off')
# plt.imshow(sample[450:550,800:900],clim=[0,100])
print(np.mean(sample[450:550,800:900]))

plt.colorbar()
# Out:
# 0.006671552453299956

# %%
path = '/srv/home/chenyu/DEbackup/071519/203.98us_delay/npy/'
rrow = 20
rcol = 20

# %%
irow = 2
icol = 16
isample = irow*rrow + icol + 1
sample = np.load(path+'S0_'+format(isample,'05')+'.npy')
sample[sample<15]=0
plt.imshow(sample[450:550,500:1000],clim=[0,100])
# plt.axis('off')
# plt.imshow(sample[450:550,800:900],clim=[0,100])
print(np.mean(sample[450:550,800:900]))
plt.colorbar()
# Out:
# 0.21746836521919977

# %%
accumulated = np.zeros((2048,2048))
for irow in range(1,rrow):
    for icol in range(rcol):
        isample = irow*rrow + icol + 1
        sample = np.load(path+'S0_'+format(isample,'05')+'.npy')
        sample[sample<50] = 0
        accumulated = accumulated + sample

# %%
plt.imshow(accumulated[300:1550,400:1550],clim=[0,500])
plt.colorbar()
