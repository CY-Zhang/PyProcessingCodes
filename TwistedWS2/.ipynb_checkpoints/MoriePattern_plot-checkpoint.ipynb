# %%
import os
import scipy.io as sio
import scipy.misc as smisc
import numpy as np
import re as regexp
import math
import matplotlib.pyplot as plt
import scipy
from PIL import Image

# %%
im = Image.open('/srv/home/chenyu/Twisted_WS2/Morie_filtered_Yuzhou/7.2MX_Filtered manually/IFFT of Maksed FFT of 14.27.36_7.2MX_1layer_1.tif')

# %%
imarray = np.array(im)

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(imarray,clim=[np.amin(imarray),np.amax(imarray)*0.9])
plt.axis('off')
# Out:
# (-0.5, 1023.5, 1023.5, -0.5)
